# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("Amazon_Final_Project.xlsx")
data
# Out:
#      Sr_no                                       Product_Name Brand_Wise_Name  \
# 0        1  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 1        2  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 2        3  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 3        4  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 4        5  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# ..     ...                                                ...             ...
# 295    296  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 296    297  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 297    298  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 298    299  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 299    300  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
#
# ...

# %%
data.shape

# %%
data.index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
data.columns
# Out:
# Index(['Sr_no', 'Product_Name', 'Brand_Wise_Name', 'Type_Of_Product',
#        'Product_Price', 'Product_Rating'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sr_no            300 non-null    int64
#  1   Product_Name     300 non-null    object
#  2   Brand_Wise_Name  300 non-null    object
#  3   Type_Of_Product  300 non-null    object
#  4   Product_Price    300 non-null    int64
#  5   Product_Rating   300 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 14.2+ KB

# %%
data.head()
# Out:
#    Sr_no                                       Product_Name Brand_Wise_Name  \
# 0      1  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 1      2  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 2      3  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 3      4  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 4      5  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
#
#   Type_Of_Product  Product_Price      Product_Rating
# 0  Semi-Automatic          12190  4.2 out of 5 stars
# 1  Semi-Automatic          12190  4.2 out of 5 stars
# 2  Semi-Automatic          12190  4.2 out of 5 stars
# 3  Semi-Automatic          12190  4.2 out of 5 stars
# 4  Semi-Automatic          12190  4.2 out of 5 stars

# %%
data.tail()
# Out:
#      Sr_no                                       Product_Name Brand_Wise_Name  \
# 295    296  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 296    297  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 297    298  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 298    299  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 299    300  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
#
#      Type_Of_Product  Product_Price      Product_Rating
# 295  Fully-Automatic          28500  4.0 out of 5 stars
# 296  Fully-Automatic          28500  4.0 out of 5 stars
# 297  Fully-Automatic          28500  4.0 out of 5 stars
# 298  Fully-Automatic          28500  4.0 out of 5 stars
# 299  Fully-Automatic          28500  4.0 out of 5 stars

# %%
data.describe()
# Out:
#             Sr_no  Product_Price
# count  300.000000     300.000000
# mean   150.500000   19623.333333
# std     86.746758    4789.871304
# min      1.000000   12190.000000
# 25%     75.750000   16490.000000
# 50%    150.500000   18470.000000
# 75%    225.250000   24990.000000
# max    300.000000   28500.000000

# %%
data.isnull().sum()    # finding null values
# Out:
# Sr_no              0
# Product_Name       0
# Brand_Wise_Name    0
# Type_Of_Product    0
# Product_Price      0
# Product_Rating     0
# dtype: int64

# %%
data[:10]
# Out:
#    Sr_no                                       Product_Name Brand_Wise_Name  \
# 0      1  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 1      2  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 2      3  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 3      4  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 4      5  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 5      6  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 6      7  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 7      8  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 8      9  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 9     10  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
#
#   Type_Of_Product  Product_Price      Product_Rating
# 0  Semi-Automatic          12190  4.2 out of 5 stars
# ...

# %%
data["Product_Name"].unique()
# Out:
# array(['LG 10 kg 5 Star Semi-Automatic Top Loading Washing Machine',
#        'Bosch 6.5 Kg 5 Star Fully Automatic Top Load Washing Machine',
#        'Voltas Beko 7Kg Semi Automatic Top Loading Washing Machine',
#        'Whirlpool  Fully-Automatic Loading Washing Machine with In-Built Heater',
#        'LG 10 Kg 5 Star Smart Inverter Fully-Automatic Top Load Washing Machine',
#        'Whirlpool 7.5 Kg 5 Star Royal Plus Fully-Automatic Top Loading Washing Machine',
#        'LG 11 kg 5 Star Semi-Automatic Top Loading Washing Machine',
#        'LG 7 Kg 5 Star Inverter Fully-Automatic Top Loading Washing Machine',
#        'LG 7 Kg 5 Star Inverter Fully-Automatic Top Loading Washing Machine ',
#        'LG P8035SRAZ 8 kg Semi Automatic Washing Machine, White',
#        'LG 7 kg 5 Star Inverter Fully-Automatic Top Loading Washing Machine',
#        'LG 6.5 Kg 5 Star Smart Inverter Fully-Automatic Top Loading Washing Machine',
# ...

# %%
data["Product_Price"].value_counts()
# Out:
# 24990    57
# 16490    38
# 18470    28
# 17490    25
# 12190    19
# 12490    19
# 16090    19
# 16690    19
# 19410    19
# 20300    19
# 25990    19
# 28500    19
# Name: Product_Price, dtype: int64

# %%
data["Brand_Wise_Name"].value_counts()
# Out:
# LG           167
# Whirlpool     38
# Bosch         19
# Voltas        19
# LG            19
# Samsung       19
# Godrej        19
# Name: Brand_Wise_Name, dtype: int64

# %%
data["Brand_Wise_Name"].value_counts().plot.bar()

# %%
data["Type_Of_Product"].value_counts()
# Out:
# Fully-Automatic     85
# Semi-Automatic      82
#  Fully-Automatic    57
# Fully Automatic     38
# Semi Automatic      38
# Name: Type_Of_Product, dtype: int64

# %%
data["Type_Of_Product"].value_counts().plot.bar()

# %%
sort1=data.sort_values(["Product_Price"],ascending="false")
sort1
# Out:
#      Sr_no                                       Product_Name Brand_Wise_Name  \
# 0        1  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 18      19  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 17      18  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 16      17  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 15      16  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# ..     ...                                                ...             ...
# 282    283  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 281    282  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 298    299  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 289    290  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 299    300  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
#
# ...

# %%
Godrej = data[data["Product_Name"] == 'LG']   # filter the dataframes by product_name      
Bosch = data[data["Product_Name"] == 'Bosch']

# %%
data.groupby(['Product_Name', 'Product_Rating']).mean()
# Out:
#                                                                        Sr_no  \
# Product_Name                                       Product_Rating
# Bosch 6.5 Kg 5 Star Fully Automatic Top Load Wa... 4.4 out of 5 stars   29.0
# Godrej 6.2 Kg Fully-Automatic Top Loading Washi... 4.0 out of 5 stars  291.0
# LG 10 Kg 5 Star Smart Inverter Fully-Automatic ... 4.4 out of 5 stars   77.0
# LG 10 kg 5 Star Semi-Automatic Top Loading Wash... 4.2 out of 5 stars   10.0
# LG 11 kg 5 Star Semi-Automatic Top Loading Wash... 4.3 out of 5 stars  127.0
# LG 6.5 Kg 5 Star Smart Inverter Fully-Automatic... 4.2 out of 5 stars  233.0
# LG 7 Kg 5 Star Inverter Fully-Automatic Top Loa... 4.4 out of 5 stars  148.5
# LG 7 Kg 5 Star Inverter Fully-Automatic Top Loa... 4.4 out of 5 stars  162.5
# LG 7 kg 5 Star Inverter Fully-Automatic Top Loa... 4.2 out of 5 stars  196.0
# LG 7 kg 5 Star Semi-Automatic Top Loading Washi... 4.5 out of 5 stars  235.0
# ...

# %%
data.nunique()
# Out:
# Sr_no              300
# Product_Name        16
# Brand_Wise_Name      7
# Type_Of_Product      5
# Product_Price       12
# Product_Rating       7
# dtype: int64

# %%
data.groupby(['Product_Price','Product_Name']).max()
# Out:
#                                                                   Sr_no  \
# Product_Price Product_Name
# 12190         LG 10 kg 5 Star Semi-Automatic Top Loading Wash...     19
# 12490         Bosch 6.5 Kg 5 Star Fully Automatic Top Load Wa...     38
# 16090         Voltas Beko 7Kg Semi Automatic Top Loading Wash...     57
# 16490         LG 10 Kg 5 Star Smart Inverter Fully-Automatic ...     95
#               Whirlpool  Fully-Automatic Loading Washing Mach...     94
# 16690         Whirlpool 7.5 Kg 5 Star Royal Plus Fully-Automa...    114
# 17490         LG 11 kg 5 Star Semi-Automatic Top Loading Wash...    139
# 18470         LG 7 Kg 5 Star Inverter Fully-Automatic Top Loa...    157
#               LG 7 Kg 5 Star Inverter Fully-Automatic Top Loa...    167
# 19410         LG P8035SRAZ 8 kg Semi Automatic Washing Machin...    186
# 20300         LG 7 kg 5 Star Inverter Fully-Automatic Top Loa...    205
# 24990         LG 6.5 Kg 5 Star Smart Inverter Fully-Automatic...    260
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Length: 300, dtype: bool

# %%
data.drop_duplicates()
# Out:
#      Sr_no                                       Product_Name Brand_Wise_Name  \
# 0        1  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 1        2  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 2        3  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 3        4  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 4        5  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# ..     ...                                                ...             ...
# 295    296  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 296    297  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 297    298  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 298    299  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 299    300  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
#
# ...

# %%
plt.hist(data.Product_Price)
plt.grid(True)
plt.show()

# %%
data.groupby('Product_Name').Brand_Wise_Name.count().plot(kind='pie')
plt.show()

# %%
data.groupby('Product_Name').Brand_Wise_Name.count()
# Out:
# Product_Name
# Bosch 6.5 Kg 5 Star Fully Automatic Top Load Washing Machine                                      19
# Godrej 6.2 Kg Fully-Automatic Top Loading Washing Machine                                         19
# LG 10 Kg 5 Star Smart Inverter Fully-Automatic Top Load Washing Machine                           19
# LG 10 kg 5 Star Semi-Automatic Top Loading Washing Machine                                        19
# LG 11 kg 5 Star Semi-Automatic Top Loading Washing Machine                                        25
# LG 6.5 Kg 5 Star Smart Inverter Fully-Automatic Top Loading Washing Machine                       19
# LG 7 Kg 5 Star Inverter Fully-Automatic Top Loading Washing Machine                               18
# LG 7 Kg 5 Star Inverter Fully-Automatic Top Loading Washing Machine                               10
# LG 7 kg 5 Star Inverter Fully-Automatic Top Loading Washing Machine                               19
# ...

# %%
data.plot(x='Brand_Wise_Name',y='Product_Rating',kind = 'scatter')
plt.show()

# %%
data.drop('Type_Of_Product', axis=1, inplace=True)

# %%
data
# Out:
#      Sr_no                                       Product_Name Brand_Wise_Name  \
# 0        1  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 1        2  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 2        3  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 3        4  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# 4        5  LG 10 kg 5 Star Semi-Automatic Top Loading Was...              LG
# ..     ...                                                ...             ...
# 295    296  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 296    297  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 297    298  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 298    299  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
# 299    300  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...          Godrej
#
# ...

# %%
data.sort_values(['Product_Name'],ascending=True)[['Product_Price','Product_Name']].head(1)          # Lowest price
# Out:
#     Product_Price                                       Product_Name
# 28          12490  Bosch 6.5 Kg 5 Star Fully Automatic Top Load W...

# %%
data.sort_values(['Product_Name'],ascending=True)[['Product_Rating','Product_Name']].head(1)          # Highest rating
# Out:
#         Product_Rating                                       Product_Name
# 28  4.4 out of 5 stars  Bosch 6.5 Kg 5 Star Fully Automatic Top Load W...

# %%
data.sort_values(['Product_Price'],ascending=False)[['Product_Price','Product_Name']].head(1)      # Highest Price
# Out:
#      Product_Price                                       Product_Name
# 299          28500  Godrej 6.2 Kg Fully-Automatic Top Loading Wash...

# %%
data['Brand_Wise_Name'].max()      # Most buying product from customer
# Out:
# 'Whirlpool'

# %%
data['Brand_Wise_Name'].min()      # least buying product from customer
# Out:
# 'Bosch'

# %%
data['Type_Of_Product'].max()       # highest type of product selling
# Out:
# 'Semi-Automatic'
